# %%
import pandas as pd
import numpy as np
import itertools
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix
import pickle
import sklearn
from sklearn import linear_model

# %%
df = pd.read_csv('drive/My Drive/Data Mining Spring 2020/Groundtruth+results.csv')
df
# Out:
#                                                 Tweet  Positive  Negative
# 0                                    covid kingcounty         1        -1
# 1   washington state reports second coronavirus death         1        -3
# 2   announcing first positive case covid new york ...         3        -1
# 3   people get coronavirus whole world wants wear ...         1        -1
# 4   theres drive thru covid test north austin doma...         1        -1
# ..                                                ...       ...       ...
# 93  coronavirus updatemeeting mayor excused restro...         1        -3
# 94  breaking second person died coronavirus covid ...         1        -2
# 95                                            florida         1        -1
# 96  coronavirus closing schools china month ago te...         2        -1
# 97  norway developed socialist country called stud...         1        -3
#
# [98 rows x 3 columns]

# %%
df["Sentiment"] = ""

# %%
for ind in df.index:
  positive = int(float(df['Positive'][ind]))
  neg = df['Negative'][ind]
  negative = float(df['Negative'][ind])
  if(positive == abs(negative)):
    df['Sentiment'][ind] = "Neutral"
  elif(positive > abs(negative)):
    df['Sentiment'][ind] = "Positve"
  else:
    df['Sentiment'][ind] = "Negative"

# %%
df
# Out:
#                                                 Tweet  ...  Sentiment
# 0                                    covid kingcounty  ...    Neutral
# 1   washington state reports second coronavirus death  ...   Negative
# 2   announcing first positive case covid new york ...  ...    Positve
# 3   people get coronavirus whole world wants wear ...  ...    Neutral
# 4   theres drive thru covid test north austin doma...  ...    Neutral
# ..                                                ...  ...        ...
# 93  coronavirus updatemeeting mayor excused restro...  ...   Negative
# 94  breaking second person died coronavirus covid ...  ...   Negative
# 95                                            florida  ...    Neutral
# 96  coronavirus closing schools china month ago te...  ...    Positve
# 97  norway developed socialist country called stud...  ...   Negative
#
# [98 rows x 4 columns]

# %%
df = df.drop(columns=['Positive','Negative'])

# %%
df
# Out:
#                                                 Tweet Sentiment
# 0                                    covid kingcounty   Neutral
# 1   washington state reports second coronavirus death  Negative
# 2   announcing first positive case covid new york ...   Positve
# 3   people get coronavirus whole world wants wear ...   Neutral
# 4   theres drive thru covid test north austin doma...   Neutral
# ..                                                ...       ...
# 93  coronavirus updatemeeting mayor excused restro...  Negative
# 94  breaking second person died coronavirus covid ...  Negative
# 95                                            florida   Neutral
# 96  coronavirus closing schools china month ago te...   Positve
# 97  norway developed socialist country called stud...  Negative
#
# [98 rows x 2 columns]

# %%
df.to_csv('drive/My Drive/Data Mining Spring 2020/Groundtruth-temp.csv')
