# %%
# import libraries

import numpy as np
import pandas as pd
from collections import Counter
import re

# %%
df_afn = pd.read_csv('src/afn/us_sentiments_analysis.csv')
df_afn
# Out:
#         date  sentiment_us        AL        AK        AZ        AR        CA  \
# 0    1/22/20     -0.229980  0.333333  0.200000  0.276596  0.045455  0.270181
# 1    1/23/20     -0.471438  0.170543  0.185714  0.138686  0.163522  0.158777
# 2    1/24/20     -0.206374  0.267898  0.296804  0.241701  0.281796  0.302619
# 3    1/25/20     -0.296810  0.201597  0.195946  0.219903  0.207243  0.262903
# 4    1/26/20     -0.249704  0.188785  0.208054  0.165341  0.194991  0.245768
# ..       ...           ...       ...       ...       ...       ...       ...
# 102  5/04/20     -0.163468  0.266369  0.289398  0.257224  0.270710  0.281416
# 103  5/05/20     -0.169094  0.291436  0.301325  0.273917  0.251830  0.273937
# 104  5/06/20     -0.160915  0.276625  0.270440  0.281277  0.271341  0.284240
# 105  5/07/20     -0.132329  0.304676  0.241042  0.287765  0.316188  0.309104
# 106  5/08/20     -0.119723  0.324607  0.284000  0.288123  0.290718  0.306142
#
# ...

# %%
df_textblob = pd.read_csv('src/textblob/us_sentiments_analysis.csv')
df_textblob
# Out:
#         date  sentiment_us        AL        AK        AZ        AR        CA  \
# 0    1/22/20      0.416963  0.571429  0.466667  0.531915  0.590909  0.551895
# 1    1/23/20      0.194959  0.387597  0.414286  0.397810  0.433962  0.446633
# 2    1/24/20      0.252480  0.461894  0.438356  0.447874  0.468828  0.433366
# 3    1/25/20      0.206506  0.423154  0.469595  0.415049  0.438632  0.412881
# 4    1/26/20      0.203046  0.429907  0.369128  0.492044  0.416816  0.484934
# ..       ...           ...       ...       ...       ...       ...       ...
# 102  5/04/20      0.134251  0.382440  0.441261  0.392902  0.378698  0.409676
# 103  5/05/20      0.179961  0.426796  0.433775  0.428031  0.453880  0.422924
# 104  5/06/20      0.164068  0.403873  0.383648  0.428157  0.413110  0.414895
# 105  5/07/20      0.174728  0.441931  0.335505  0.436434  0.438729  0.436690
# 106  5/08/20      0.187647  0.436300  0.452000  0.452490  0.448336  0.439498
#
# ...

# %%
df_vader = pd.read_csv('src/vader/us_sentiments_analysis.csv')
df_vader
# Out:
#         date  sentiment_us        AL        AK        AZ        AR        CA  \
# 0    1/22/20     -0.052268  0.380952  0.400000  0.329787  0.181818  0.317957
# 1    1/23/20     -0.264139  0.271318  0.271429  0.213504  0.226415  0.253161
# 2    1/24/20      0.007633  0.339492  0.356164  0.338963  0.331671  0.385674
# 3    1/25/20     -0.056723  0.277445  0.270270  0.300485  0.275654  0.358670
# 4    1/26/20     -0.090386  0.272897  0.297539  0.212829  0.270125  0.293817
# ..       ...           ...       ...       ...       ...       ...       ...
# 102  5/04/20     -0.048433  0.358631  0.352436  0.322550  0.359467  0.340177
# 103  5/05/20     -0.034457  0.378453  0.367550  0.355627  0.348463  0.343067
# 104  5/06/20     -0.044504  0.348548  0.345912  0.333527  0.317073  0.348173
# 105  5/07/20     -0.020378  0.333333  0.302932  0.349985  0.375189  0.372414
# 106  5/08/20     -0.011160  0.357766  0.332000  0.353257  0.323993  0.361860
#
# ...

# %%
df_ensemble = pd.read_csv('src/ensemble/us_sentiments_analysis.csv')
df_ensemble
# Out:
#         date  sentiment_us        AL        AK        AZ        AR        CA  \
# 0    1/22/20     -0.168639  0.333333  0.266667  0.276596  0.136364  0.293245
# 1    1/23/20     -0.404321  0.209302  0.242857  0.167883  0.169811  0.186416
# 2    1/24/20     -0.134307  0.297921  0.333333  0.287129  0.296758  0.337713
# 3    1/25/20     -0.220988  0.231537  0.226351  0.238350  0.223340  0.295247
# 4    1/26/20     -0.197991  0.209346  0.237136  0.180507  0.218247  0.261350
# ..       ...           ...       ...       ...       ...       ...       ...
# 102  5/04/20     -0.106193  0.303571  0.323782  0.287688  0.315089  0.310265
# 103  5/05/20     -0.105504  0.341160  0.327815  0.314045  0.292826  0.305835
# 104  5/06/20     -0.101089  0.318119  0.317610  0.318142  0.291159  0.320279
# 105  5/07/20     -0.079519  0.313725  0.273616  0.318576  0.344932  0.340077
# 106  5/08/20     -0.063271  0.329843  0.316000  0.321456  0.313485  0.333220
#
# ...

# %%
df_corr = pd.read_csv('src/us_correlation_analysis.csv')
df_corr
# Out:
#         date    tweets    cases  cases_daily  tweets_daily
# 0    1/22/20      5070        1            1          5070
# 1    1/23/20     29788        1            0         24718
# 2    1/24/20    104594        2            1         74806
# 3    1/25/20    189463        2            0         84869
# 4    1/26/20    297655        5            3        108192
# ..       ...       ...      ...          ...           ...
# 102   5/4/20  13601803  1180375        22335        115686
# 103   5/5/20  13724102  1204351        23976        122299
# 104   5/6/20  13848764  1229331        24980        124662
# 105   5/7/20  13967566  1257023        27692        118802
# 106   5/8/20  14067296  1283929        26906         99730
#
# [107 rows x 5 columns]

# %%
df_all = df_corr[['date', 'cases_daily', 'tweets_daily']]
df_all
# Out:
#         date  cases_daily  tweets_daily
# 0    1/22/20            1          5070
# 1    1/23/20            0         24718
# 2    1/24/20            1         74806
# 3    1/25/20            0         84869
# 4    1/26/20            3        108192
# ..       ...          ...           ...
# 102   5/4/20        22335        115686
# 103   5/5/20        23976        122299
# 104   5/6/20        24980        124662
# 105   5/7/20        27692        118802
# 106   5/8/20        26906         99730
#
# [107 rows x 3 columns]

# %%
df_all['cases_total'] = df_corr['cases']
df_all['tweets_total'] = df_corr['tweets']
df_all
# Out:
# /Users/allen/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
#         date  cases_daily  tweets_daily  cases_total  tweets_total
# 0    1/22/20            1          5070            1          5070
# 1    1/23/20            0         24718            1         29788
# 2    1/24/20            1         74806            2        104594
# 3    1/25/20            0         84869            2        189463
# 4    1/26/20            3        108192            5        297655
# ..       ...          ...           ...          ...           ...
# 102   5/4/20        22335        115686      1180375      13601803
# ...

# %%
df_all['sentiment_afn'] = df_afn['sentiment_us']
df_all['sentiment_ensemble'] = df_ensemble['sentiment_us']
df_all['sentiment_textblob'] = df_textblob['sentiment_us']
df_all['sentiment_vader'] = df_vader['sentiment_us']
df_all
# Out:
#         date  cases_daily  tweets_daily  cases_total  tweets_total  \
# 0    1/22/20            1          5070            1          5070
# 1    1/23/20            0         24718            1         29788
# 2    1/24/20            1         74806            2        104594
# 3    1/25/20            0         84869            2        189463
# 4    1/26/20            3        108192            5        297655
# ..       ...          ...           ...          ...           ...
# 102   5/4/20        22335        115686      1180375      13601803
# 103   5/5/20        23976        122299      1204351      13724102
# 104   5/6/20        24980        124662      1229331      13848764
# 105   5/7/20        27692        118802      1257023      13967566
# 106   5/8/20        26906         99730      1283929      14067296
#
#      sentiment_afn  sentiment_ensemble  sentiment_textblob  sentiment_vader
# 0        -0.229980           -0.168639            0.416963        -0.052268
# ...

# %%
df_all.to_csv('src/us_sentiment_models.csv')
